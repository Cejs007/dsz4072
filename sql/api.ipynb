# %%
import requests
import json

# %%
url_start = "https://api.openweathermap.org/data/2.5/forecast?q="
url_end = "&appid=ba8fc0c7c0af9f0c2a2e114fc9850623&units=metric"

# %%
mesto = input("Zadej město: ")

# %%
url = url_start + mesto + url_end

# %%
response = requests.get(url)

# %%
json.loads(response.text)
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1727006400,
#    'main': {'temp': 22.92,
#     'feels_like': 22.23,
#     'temp_min': 21.32,
#     'temp_max': 22.92,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 983,
#     'humidity': 37,
#     'temp_kf': 1.6},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 4.97, 'deg': 150, 'gust': 6.74},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-09-22 12:00:00'},
#   {'dt': 1727017200,
#    'main': {'temp': 22.15,
#     'feels_like': 21.52,
#     'temp_min': 20.61,
#     'temp_max': 22.15,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 982,
#     'humidity': 42,
#     'temp_kf': 1.54},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 2},
# ...
